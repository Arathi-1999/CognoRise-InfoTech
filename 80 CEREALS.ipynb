# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('cereal.CSV')

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 8.8+ KB

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
# Remove negative values from sugars and potass columns
df=df[(df['sugars']>0 ) & (df['potass']>0)]
df
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 0                 100% Bran   N    C        70        4    1     130   10.0
# 1         100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                  All-Bran   K    C        70        4    1     260    9.0
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6               Apple Jacks   K    C       110        2    0     125    1.0
# ..                      ...  ..  ...       ...      ...  ...     ...    ...
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   68.000000  68.000000  68.000000   68.000000  68.000000  68.000000
# mean   110.441176   2.514706   1.088235  174.632353   2.000000  14.764706
# std     15.875808   1.085765   1.003506   73.053426   2.029631   3.838601
# min     70.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  140.000000   0.000000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.500000
# 75%    120.000000   3.000000   2.000000  220.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  10.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  68.000000   68.000000   68.000000  68.000000  68.000000  68.000000
# mean    7.735294   96.176471   31.250000   2.235294   1.050735   0.822941
# std     3.972358   67.054876   21.758083   0.812544   0.127224   0.238497
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['mfr'].value_counts()
# Out:
# K    22
# G    22
# P     9
# R     7
# Q     5
# N     2
# A     1
# Name: mfr, dtype: int64

# %%
manufacture ={
    'K':'Kelloggs',
    'G': 'General Mills',
    'P': 'Post',
    'R': 'Ralston Purina',
    'Q': 'Quaker Oats',
    'N': 'Nabisco',
    'A': 'American Home Food Products'
}
df['mfr']=df['mfr'].map(manufacture)
# Out:
# C:\Users\Arati\AppData\Local\Temp\ipykernel_1316\1840418574.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mfr']=df['mfr'].map(manufacture)

# %%
df['mfr'].unique()
# Out:
# array(['Nabisco', 'Quaker Oats', 'Kelloggs', 'General Mills',
#        'Ralston Purina', 'Post', 'American Home Food Products'],
#       dtype=object)

# %%
# explore the distribution of cereals types

cereal_type=df['type'].value_counts()
cereal_type
# Out:
# C    67
# H     1
# Name: type, dtype: int64

# %%
# numerical features
numerical_columns=['calories','sugars','protein','fat','sodium','fiber','carbo','potass','vitamins','weight','cups']
df[numerical_columns].describe()
# Out:
#          calories     sugars    protein        fat      sodium      fiber  \
# count   68.000000  68.000000  68.000000  68.000000   68.000000  68.000000
# mean   110.441176   7.735294   2.514706   1.088235  174.632353   2.000000
# std     15.875808   3.972358   1.085765   1.003506   73.053426   2.029631
# min     70.000000   1.000000   1.000000   0.000000    0.000000   0.000000
# 25%    100.000000   3.750000   2.000000   0.000000  140.000000   0.000000
# 50%    110.000000   7.500000   2.500000   1.000000  180.000000   1.750000
# 75%    120.000000  11.000000   3.000000   2.000000  220.000000   3.000000
# max    160.000000  15.000000   6.000000   5.000000  320.000000  10.000000
#
#            carbo      potass    vitamins     weight       cups
# count  68.000000   68.000000   68.000000  68.000000  68.000000
# mean   14.764706   96.176471   31.250000   1.050735   0.822941
# std     3.838601   67.054876   21.758083   0.127224   0.238497
# ...

# %%
# Bar chart shows the count of cereals  by manufacture

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='mfr')
plt.xlabel('Manufacture')
plt.ylabel('Cereal type')
plt.title('Count of cereal by manufacture',fontsize=10)
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of calories
plt.figure(figsize=(10,6))
sns.histplot(df['calories'],bins=10,edgecolor='black')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.title('distribution of calories')
plt.show()

# %%
df['vitamins'].describe()
# Out:
# count     68.000000
# mean      31.250000
# std       21.758083
# min        0.000000
# 25%       25.000000
# 50%       25.000000
# 75%       25.000000
# max      100.000000
# Name: vitamins, dtype: float64

# %%
# Visualize the distribution of vitamins

plt.figure(figsize=(10,6))
sns.histplot(df['vitamins'],bins=3,edgecolor='black')
plt.xlabel('Vitamins')
plt.ylabel('Frequency')
plt.title('Distribution of Vitamins',fontsize=9)
plt.xticks([0,25,100],['0%','25%','100%'])
plt.show()

# %%
# statistics summary of rating grouped by shelf 
rating=df.groupby('shelf')['rating'].describe()
rating

# %%
# plot the graph of rating bu shelf placements

plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='shelf',y='rating')
plt.xlabel('Shelf')
plt.ylabel('Rating')
plt.title('Relationship between shelf placement and Rating')
plt.show()

# %%
# Top 10 cereals with highest rating
top_cereals=df.nlargest(10,'rating')
top_cereals
# Out:
#                        name                          mfr type  calories  \
# 0                 100% Bran                      Nabisco    C        70
# 50        Nutri-grain Wheat                     Kelloggs    C        90
# 2                  All-Bran                     Kelloggs    C        70
# 68  Strawberry Fruit Wheats                      Nabisco    C        90
# 26      Frosted Mini-Wheats                     Kelloggs    C       100
# 60           Raisin Squares                     Kelloggs    C        90
# 43                    Maypo  American Home Food Products    H       100
# 33               Grape-Nuts                         Post    C       110
# 9               Bran Flakes                         Post    C        90
# 67                Special K                     Kelloggs    C       110
#
#     protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  \
# 0         4    1     130   10.0    5.0       6     280        25      3
# ...

# %%
# create a plot
plt.figure(figsize=(10,6))
plt.bar(top_cereals['name'],top_cereals['rating'])
plt.xlabel('Rating')
plt.ylabel('Cereals')
plt.title('Top 10 cereals with the highest rating')
plt.show()

# %%
# Bottom 10 cereals with the lowest ratings
lowest_cereals=df.nsmallest(10,'rating')
lowest_cereals
# Out:
#                      name            mfr type  calories  protein  fat  sodium  \
# 10           Cap'n'Crunch    Quaker Oats    C       120        1    2     220
# 12  Cinnamon Toast Crunch  General Mills    C       120        1    3     210
# 35       Honey Graham Ohs    Quaker Oats    C       120        1    2     220
# 18          Count Chocula  General Mills    C       110        1    1     180
# 14            Cocoa Puffs  General Mills    C       110        1    1     180
# 31         Golden Grahams  General Mills    C       110        1    1     280
# 42           Lucky Charms  General Mills    C       110        2    1     180
# 73                   Trix  General Mills    C       110        1    1     140
# 29         Fruity Pebbles           Post    C       110        1    1     135
# 70      Total Raisin Bran  General Mills    C       140        3    1     190
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
# visualize the plot
plt.figure(figsize=(10,6))
plt.bar(lowest_cereals['name'],lowest_cereals['rating'])
plt.xlabel('Cereals')
plt.ylabel('Ratings')
plt.title('Bottom 10 cereals with the lowest ratings')
plt.show()

# %%
# plot calories vs proteins
plt.scatter(df['calories'],df['protein'])
plt.xlabel('Calories')
plt.ylabel('Proteins')
plt.title('Calories vs Proteins')
plt.show()

# %%
sns.scatterplot(df['calories'],df['protein'])
plt.title('Calories vs Proteins')
# Out:
# C:\Users\Arati\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Calories vs Proteins')

# %%
# visualize relation between calories and ratings

sns.scatterplot(df['calories'],df['rating'])
plt.title('Relation between Calories and Ratings')
# Out:
# C:\Users\Arati\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Relation between Calories and Ratings')

# %%
# visualize the relation between sugar and rating

sns.regplot(df['sugars'],df['rating'])
plt.show()
# Out:
# C:\Users\Arati\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Relation between calories and ratings
sns.regplot(df['calories'],df['rating'])
# Out:
# C:\Users\Arati\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='calories', ylabel='rating'>

# %%
# Relation between fiber and ratings
sns.regplot(df['fiber'],df['rating'])
# Out:
# C:\Users\Arati\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fiber', ylabel='rating'>

# %%
# Distribution of ratings
plt.figure(figsize=(10,8))
plt.hist(df['rating'])
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
df.corr()
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.021265  0.456576  0.038106 -0.206126  0.235623
# protein   0.021265  1.000000  0.217966 -0.027686  0.511351 -0.036759
# fat       0.456576  0.217966  1.000000 -0.183803  0.113585 -0.325812
# sodium    0.038106 -0.027686 -0.183803  1.000000 -0.060901  0.439055
# fiber    -0.206126  0.511351  0.113585 -0.060901  1.000000 -0.389852
# carbo     0.235623 -0.036759 -0.325812  0.439055 -0.389852  1.000000
# sugars    0.425517 -0.341675  0.170691 -0.281675 -0.044429 -0.565990
# potass   -0.001897  0.552241  0.269039 -0.065647  0.914078 -0.373787
# vitamins  0.110722  0.035538 -0.145259  0.179877 -0.025348  0.303795
# shelf     0.188527  0.232868  0.285335 -0.238648  0.398211 -0.101616
# weight    0.601348  0.180902  0.119897  0.092207  0.332647  0.097088
# cups      0.125399 -0.196138 -0.176339  0.171050 -0.516464  0.394486
# rating   -0.570107  0.583036 -0.306151 -0.159142  0.555233  0.134003
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['name'],axis=1,inplace=True)
# Out:
# C:\Users\Arati\AppData\Local\Temp\ipykernel_1316\2714769439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#              mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 0        Nabisco    C        70        4    1     130   10.0    5.0       6
# 1    Quaker Oats    C       120        3    5      15    2.0    8.0       8
# 2       Kelloggs    C        70        4    1     260    9.0    7.0       5
# 5  General Mills    C       110        2    2     180    1.5   10.5      10
# 6       Kelloggs    C       110        2    0     125    1.0   11.0      14
#
#    potass  vitamins  shelf  weight  cups     rating
# 0     280        25      3     1.0  0.33  68.402973
# 1     135         0      3     1.0  1.00  33.983679
# 2     320        25      3     1.0  0.33  59.425505
# 5      70        25      1     1.0  0.75  29.509541
# 6      30        25      2     1.0  1.00  33.174094

# %%
x=df.drop(['rating','mfr','shelf','type','carbo','vitamins','weight','cups'],axis=1)
y=df['rating']

# %%
# splitting dataset as train and test set 

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.head()
# Out:
#     calories  protein  fat  sodium  fiber  sugars  potass
# 34       120        3    3      75    3.0       4     100
# 68        90        2    0      15    3.0       5      90
# 52       120        3    1     200    6.0      14     260
# 47       100        2    1     220    2.0       6      90
# 24       110        2    1     125    1.0      13      30

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
model=LinearRegression()
model.fit(x_train,y_train)
print(cross_val_score(model,x,y,cv=10).mean())
print(model.score(x,y))
# Out:
# 0.969266533530918
# 0.9809726477784084

# %%
sns.regplot(x=y_test,y=y_pred)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error
from sklearn import tree
from math import sqrt

tree=DecisionTreeRegressor()
tree.fit(x_train,y_train)
y_pred_train=tree.predict(x_train)
y_pred=tree.predict(x_test)
print(sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 4.980649134043969

# %%
from sklearn.model_selection import GridSearchCV
params={
    'max_depth':[10,15,20,40,50],
    'min_samples_split':[2,4,6,8,10],
    'min_samples_leaf':[2,4,5,7,8]}
model=GridSearchCV(tree,params,n_jobs=-1)
model.fit(x_train,y_train)
print(model.best_params_)
# Out:
# {'max_depth': 50, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
tree1=DecisionTreeRegressor(max_depth=40,min_samples_leaf=2,min_samples_split=2)
tree1.fit(x_train,y_train)
y_pred=tree1.predict(x_test)
print(r2_score(y_test,y_pred))
print(sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 0.6782488561006632
# 5.952202718749313
