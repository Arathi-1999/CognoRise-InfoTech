# %%
# importing libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as  sns

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# # EDA

# %%
# checking dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
# checking stastitical analysis of categorical values
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# checking the duplicated data

df.duplicated().sum()
# Out:
# 240

# %%
# to drop the duplicates

df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1359, 12)

# %%
# checking the sample size of whole data

df.sample()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 23            8.5              0.49         0.11             2.3      0.084
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 23                  9.0                  67.0   0.9968  3.17       0.53
#
#     alcohol  quality
# 23      9.4        5

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Univarient analysis

# %%
# shows how the data is distributed and it also shows any outliers

for i in df.columns:
    if df[i].dtypes!='object':
        sns.boxplot(y=df[i])
        plt.show()

# %%
# to check whether it is uniform distribution or not

for i in df.columns:
    if df[i].dtypes!='object':
        sns.histplot(x=df[i])
        plt.show()

# %% [markdown]
# # KDE plot

# %%
# to check whether it is uniform distribution or not

for i in df.columns:
    if df[i].dtypes!='object':
        sns.kdeplot(x=df[i])
        plt.show()

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # 1. Line plot

# %%
# to connect a series of data points using a line

sns.lineplot('alcohol','residual sugar',data=df , ci=None)
plt.title('Alcohol vs Residual_sugar')
plt.show()

# %% [markdown]
# # Label encoding the categorical columns

# %%
# encoding the categorical data to numerical
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['density']=le.fit_transform(df['density'])
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0      342  3.51       0.56
# 1                 25.0                  67.0      271  3.20       0.68
# 2                 15.0                  54.0      287  3.26       0.65
# 3                 17.0                  60.0      354  3.16       0.58
# 5                 13.0                  40.0      342  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x =df[['fixed acidity']].values
x1= sc.fit_transform(x)
x1
# Out:
# array([[-0.52443096],
#        [-0.29406274],
#        [-0.29406274],
#        ...,
#        [-1.38831178],
#        [-1.38831178],
#        [-1.33071973]])

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.626231          0.023786     0.338581
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# checking the correlation with the target 'Alcohol'

sns.heatmap(df.corr()[['alcohol']].sort_values(by='alcohol',ascending=False))
# Out:
# <AxesSubplot:>

# %%
# drop target values from the x variable

x=df[['volatile acidity','citric acid','pH','sulphates']].values

# %%
y=df[['alcohol']].values

# %%
x=sc.fit_transform(x)

# %% [markdown]
# # model building

# %%
from sklearn.ensemble import AdaBoostRegressor,RandomForestRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.tree import DecisionTreeRegressor

# %%
models={
    'LinearRegression': LinearRegression(),
    'Ridge':Ridge(),
    'AdaBoostRegressor':AdaBoostRegressor(),
    'DecisionTreeRegressor': DecisionTreeRegressor(),
    'RandomForestRegressor': RandomForestRegressor(),
    'GradientBoostingRegressor': GradientBoostingRegressor()
}

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
for name, model in models.items():
    scores = cross_val_score(model,x,y,scoring='neg_mean_squared_error',cv=20)
    print('Cross validation model:{}'.format(name))
    rmse = np.sqrt(-scores)
    rmse_average = np.mean(rmse)
    print('Average RMSE:',rmse_average)
    print('*'*100)
# Out:
# Cross validation model:LinearRegression
# Average RMSE: 1.0084553771777454
# ****************************************************************************************************
# Cross validation model:Ridge
# Average RMSE: 1.0084501885676656
# ****************************************************************************************************
# Cross validation model:AdaBoostRegressor
# Average RMSE: 1.052326419674364
# ****************************************************************************************************
# Cross validation model:DecisionTreeRegressor
# Average RMSE: 1.3316279281411683
# ****************************************************************************************************
# Cross validation model:RandomForestRegressor
# Average RMSE: 0.9816506818656185
# ****************************************************************************************************
# Cross validation model:GradientBoostingRegressor
# Average RMSE: 0.9692018706778489
# ...

# %% [markdown]
# # selecting Random forest regressor as it is having best metrics

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x)

# %%
output= pd.DataFrame(zip(y,y_pred),columns=('Actual','Prediction'),dtype=float)

# %%
output.head()
# Out:
#    Actual  Prediction
# 0     9.4   10.011000
# 1     9.8    9.921667
# 2     9.8    9.777167
# 3     9.8   10.268000
# 4     9.4   10.634000

# %% [markdown]
# # scatter plot

# %%
model.score(x,y)*100
# Out:
# 72.69184805958757

# %%
plt.figure(figsize=(18,6))
plt.title('Actual vs Prediction')
sns.scatterplot(data=output,x='Actual',y='Prediction');
